# %% [markdown]
# **CNN A.F.A.N.E**

# %%
# Install dependencies from requirements.txt
# %pip install -r content/requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 7)) (2.7.1+cu118)
# Requirement already satisfied: torchvision>=0.15.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 8)) (0.22.1+cu118)
# Requirement already satisfied: scikit-learn>=1.3.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 11)) (1.9.0)
# Requirement already satisfied: Pillow>=10.0.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 14)) (12.2.0)
# Requirement already satisfied: opencv-python>=4.8.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 15)) (4.13.0.92)
# Requirement already satisfied: albumentations>=1.3.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 16)) (2.0.8)
# Requirement already satisfied: numpy>=1.24.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 19)) (2.4.6)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 22)) (3.11.0)
# Requirement already satisfied: seaborn>=0.12.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 23)) (0.13.2)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from -r content/requirements.txt (line 29)) (4.68.2)
# Requirement already satisfied: filelock in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: fsspec in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (2026.4.0)
# Requirement already satisfied: setuptools in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from torch>=2.0.0->-r content/requirements.txt (line 7)) (81.0.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.3.0->-r content/requirements.txt (line 11)) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.3.0->-r content/requirements.txt (line 11)) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.3.0->-r content/requirements.txt (line 11)) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-learn>=1.3.0->-r content/requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: PyYAML in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from albumentations>=1.3.0->-r content/requirements.txt (line 16)) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from albumentations>=1.3.0->-r content/requirements.txt (line 16)) (2.12.5)
# Requirement already satisfied: albucore==0.0.24 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from albumentations>=1.3.0->-r content/requirements.txt (line 16)) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from albumentations>=1.3.0->-r content/requirements.txt (line 16)) (4.13.0.92)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from albucore==0.0.24->albumentations>=1.3.0->-r content/requirements.txt (line 16)) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from albucore==0.0.24->albumentations>=1.3.0->-r content/requirements.txt (line 16)) (6.5.16)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (26.2)
# Requirement already satisfied: pyparsing>=3 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from seaborn>=0.12.0->-r content/requirements.txt (line 23)) (3.0.3)
# Requirement already satisfied: colorama in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm>=4.65.0->-r content/requirements.txt (line 29)) (0.4.6)
# Requirement already satisfied: tzdata in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas>=1.2->seaborn>=0.12.0->-r content/requirements.txt (line 23)) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.9.2->albumentations>=1.3.0->-r content/requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.9.2->albumentations>=1.3.0->-r content/requirements.txt (line 16)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=2.9.2->albumentations>=1.3.0->-r content/requirements.txt (line 16)) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r content/requirements.txt (line 22)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->-r content/requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2->torch>=2.0.0->-r content/requirements.txt (line 7)) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# """
# BananaVision — Module A : Architecture CNN (Transfer Learning)
# PHP Plantations du Haut-Penja — UCAC-ICAM 2026
#
# Ce module implémente les deux architectures comparées :
#   1. MobileNetV2  (Google, 2018) — léger, rapide, temps réel
#   2. EfficientNet-B0 (Google Brain, 2019) — plus précis, compound scaling
#
# STRATÉGIE DE TRANSFER LEARNING CHOISIE :
#   Phase 1 — Feature Extraction (Epochs 1-10) :
#     → Toutes les couches pré-entraînées GELÉES (requires_grad=False)
#     → Seule la tête de classification est entraînée
#     → Learning rate élevé (1e-3) : la tête part de zéro
#     POURQUOI : éviter de "désapprendre" les features ImageNet dès le début
#
#   Phase 2 — Fine-tuning (Epochs 11-20) :
#     → Les derniers blocs du backbone sont DÉGELÉS
#     → Learning rate très faible (1e-5) : ajustements fins seulement
#     POURQUOI : adapter les features de haut niveau aux spécificités
#     des bananes du Mungo (éclairage pack-house, fond tapis convoyeur)
#
# JUSTIFICATION DU CHOIX ARCHITECTUREL POUR LE RAPPORT :
#   - VGG-16 : 138M paramètres → overfitting certain sur < 10 000 images
#   - ResNet-50 : 25M params → acceptable mais temps d'inférence > 100ms
#   - MobileNetV2 : 3.4M params, 30ms → compatible convoyeur PHP (5s/banane)
#   - EfficientNet-B0 : 5.3M params, 50ms → meilleur accuracy/taille ratio
# """

# %%
import torch
import torch.nn as nn
from torchvision import models
from typing import Literal


print(f"CUDA disponible : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU : {torch.cuda.get_device_name(0)}")


# ─────────────────────────────────────────────────────────────────
# BUILDER PRINCIPAL
# ─────────────────────────────────────────────────────────────────

def build_model(
    architecture: Literal["mobilenet_v2", "efficientnet_b0"],
    num_classes: int,
    task: Literal["binary", "multiclass"] = "binary",
    freeze_backbone: bool = True,
) -> nn.Module:
    """
    Construit et retourne le modèle CNN avec tête de classification adaptée.

    Args:
        architecture: "mobilenet_v2" ou "efficientnet_b0"
        num_classes: 2 pour binaire, N pour multi-classes
        task: "binary" (sigmoid) ou "multiclass" (softmax implicite dans CrossEntropy)
        freeze_backbone: True = Phase 1 (feature extraction)
                         False = Phase 2 (fine-tuning)
    Returns:
        nn.Module : modèle PyTorch prêt pour l'entraînement
    """
    if architecture == "mobilenet_v2":
        return _build_mobilenet_v2(num_classes, task, freeze_backbone)
    elif architecture == "efficientnet_b0":
        return _build_efficientnet_b0(num_classes, task, freeze_backbone)
    else:
        raise ValueError(f"Architecture inconnue : {architecture}. Choisir 'mobilenet_v2' ou 'efficientnet_b0'")


def _build_mobilenet_v2(num_classes: int, task: str, freeze_backbone: bool) -> nn.Module:
    """
    MobileNetV2 avec tête de classification PHP personnalisée.

    ARCHITECTURE INTERNE MobileNetV2 :
    Input (3×224×224)
    → Conv2d initiale
    → 17 Blocs Inversés Résiduels (InvertedResidual)
      [c'est ici que résident les features visuelles génériques d'ImageNet]
    → Conv2d finale → AdaptiveAvgPool → Dropout
    → Linear(1280 → num_classes)  ← CETTE COUCHE SEULEMENT est remplacée

    BLOC INVERSÉ RÉSIDUEL (différence clé avec ResNet) :
    Au lieu d'élargir puis rétrécir les canaux (ResNet),
    MobileNetV2 rétrécit d'abord (bottleneck), applique une conv depthwise
    (1 filtre par canal, très efficace), puis ré-élargit.
    Résultat : ~10x moins d'opérations que ResNet pour une qualité similaire.
    """
    # Chargement des poids pré-entraînés sur ImageNet
    weights = models.MobileNet_V2_Weights.IMAGENET1K_V1
    model = models.mobilenet_v2(weights=weights)

    # Gel du backbone
    if freeze_backbone:
        for param in model.parameters():
            param.requires_grad = False
        print("[MobileNetV2] Backbone gelé — seule la tête sera entraînée")
    else:
        # Phase 2 : dégeler les 5 derniers blocs (features de haut niveau)
        # Les premiers blocs restent gelés : ils détectent des primitives
        # (bords, coins) qui sont universelles et n'ont pas besoin d'adaptation
        _unfreeze_last_n_layers(model.features, n=5)
        print("[MobileNetV2] Fine-tuning : 5 derniers blocs dégelés")

    # Remplacement de la tête de classification
    # model.classifier[1] est le Linear(1280 → 1000) d'ImageNet
    in_features = model.classifier[1].in_features  # = 1280

    model.classifier = _build_head(in_features, num_classes, task)

    _print_trainable_params(model, "MobileNetV2")
    return model


def _build_efficientnet_b0(num_classes: int, task: str, freeze_backbone: bool) -> nn.Module:
    """
    EfficientNet-B0 avec tête de classification PHP personnalisée.

    COMPOUND SCALING — ce qui rend EfficientNet unique :
    Les architectures classiques agrandissent le réseau selon UNE dimension :
    - Profondeur (plus de couches) → ResNet, VGG
    - Largeur (plus de filtres par couche) → Wide ResNet
    - Résolution (images plus grandes) → pas standard

    EfficientNet prouve mathématiquement qu'il faut scaler les TROIS ensemble
    avec un ratio constant (φ = coefficient de scaling) :
    - depth    d = α^φ  (α = 1.2 pour B0)
    - width    w = β^φ  (β = 1.1)
    - resolution r = γ^φ (γ = 1.15)

    EfficientNet-B0 est le modèle de base (φ=1). B1 à B7 sont des versions
    plus grandes. B0 est optimal pour notre petit dataset PHP.
    """
    weights = models.EfficientNet_B0_Weights.IMAGENET1K_V1
    model = models.efficientnet_b0(weights=weights)

    if freeze_backbone:
        for param in model.parameters():
            param.requires_grad = False
        print("[EfficientNet-B0] Backbone gelé")
    else:
        _unfreeze_last_n_layers(model.features, n=3)
        print("[EfficientNet-B0] Fine-tuning : 3 derniers blocs dégelés")

    # EfficientNet-B0 : sortie du backbone = 1280 features (même que MobileNetV2)
    in_features = model.classifier[1].in_features  # = 1280

    model.classifier = _build_head(in_features, num_classes, task)

    _print_trainable_params(model, "EfficientNet-B0")
    return model


# ─────────────────────────────────────────────────────────────────
# FONCTIONS UTILITAIRES
# ─────────────────────────────────────────────────────────────────

def _build_head(in_features: int, num_classes: int, task: str) -> nn.Sequential:
    """
    Construit la tête de classification adaptée à la tâche PHP.

    POURQUOI Dropout(0.3) ?
    Avec ~5000 images, le modèle risque de mémoriser les exemples d'entraînement.
    Le Dropout désactive aléatoirement 30% des neurones à chaque passe
    → force le réseau à apprendre des représentations robustes et redondantes.

    BINAIRE vs MULTI-CLASSES :
    - Binaire : 1 neurone de sortie + sigmoid → probabilité [0,1] d'être "rejeté"
      Utilisé avec BCEWithLogitsLoss (numériquement stable)
    - Multi-classes : N neurones + pas d'activation → probas via softmax implicite
      Utilisé avec CrossEntropyLoss (= LogSoftmax + NLLLoss)
    """
    if task == "binary":
        return nn.Sequential(
            nn.Dropout(p=0.3),
            nn.Linear(in_features, 256),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(256, 1),   # 1 seul neurone pour binaire
            # PAS de sigmoid ici ! BCEWithLogitsLoss l'inclut, plus stable
        )
    else:  # multiclass
        return nn.Sequential(
            nn.Dropout(p=0.3),
            nn.Linear(in_features, 256),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(256, num_classes),  # N neurones pour N classes
            # PAS de softmax ici ! CrossEntropyLoss l'inclut
        )


def _unfreeze_last_n_layers(feature_extractor: nn.Sequential, n: int) -> None:
    """Dégèle les n derniers blocs du backbone pour le fine-tuning."""
    layers = list(feature_extractor.children())
    for layer in layers[-n:]:
        for param in layer.parameters():
            param.requires_grad = True


def _print_trainable_params(model: nn.Module, name: str) -> None:
    """Affiche le nombre de paramètres entraînables vs total."""
    total  = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"[{name}] Params total: {total:,} | Entraînables: {trainable:,} "
          f"({100*trainable/total:.1f}%)")


def get_optimizer(model: nn.Module, phase: int = 1) -> torch.optim.Optimizer:
    """
    Retourne l'optimiseur adapté à la phase d'entraînement.

    Phase 1 (backbone gelé) : Adam lr=1e-3 sur la tête seulement
    Phase 2 (fine-tuning)   : Adam avec lr différencié :
        - Backbone dégelé : lr=1e-5 (très faible → ajustements fins)
        - Tête            : lr=1e-4 (modéré → la tête continue à apprendre)

    POURQUOI Adam et pas SGD ?
    Adam adapte le learning rate par paramètre → converge plus vite sur
    les petits datasets. SGD avec momentum est supérieur sur très grands
    datasets (ImageNet complet) mais requiert plus d'epochs pour converger.
    """
    if phase == 1:
        params = filter(lambda p: p.requires_grad, model.parameters())
        return torch.optim.Adam(params, lr=1e-3, weight_decay=1e-4)
    else:
        # Learning rates différenciés backbone vs tête
        backbone_params = []
        head_params = []
        for name, param in model.named_parameters():
            if param.requires_grad:
                if "classifier" in name:
                    head_params.append(param)
                else:
                    backbone_params.append(param)
        return torch.optim.Adam([
            {"params": backbone_params, "lr": 1e-5},
            {"params": head_params,     "lr": 1e-4},
        ], weight_decay=1e-4)
# Out:
# CUDA disponible : True
# GPU : NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %% [markdown]
# """
# BananaVision — Module A : Prétraitement des données
# PHP Plantations du Haut-Penja — UCAC-ICAM 2026
#
# Ce module gère :
#   - Le chargement du dataset depuis un répertoire structuré
#   - Le redimensionnement et la normalisation des images
#   - L'augmentation de données pour compenser le petit dataset
#   - La création des DataLoaders pour l'entraînement
#
# Structure attendue du dataset :
#     dataset/
#         export/          ← images bananes conformes (Catégorie Extra ou I)
#         rejete/          ← images bananes non conformes (Hors catégorie)
#         defaut_mur/      ← bananes trop mûres (stade 6-7) → farine
#         defaut_fongique/ ← cercosporiose, moisissures
#         defaut_mecanique/← bruises, déformations
#         defaut_calibre/  ← longueur < 14cm ou grade < 27mm
# """

# %%
import os
from pathlib import Path

import torch
from torch.utils.data import DataLoader, random_split, WeightedRandomSampler
from torchvision import datasets, transforms
import numpy as np


# ─────────────────────────────────────────────────────────────────
# Constantes MobileNetV2 / EfficientNet-B0
# Les deux architectures attendent des images 224×224 normalisées
# avec les moyennes et écart-types d'ImageNet (car pré-entraînées dessus)
# ─────────────────────────────────────────────────────────────────
IMG_SIZE = 224
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

# Proportions train / validation / test
TRAIN_RATIO = 0.70
VAL_RATIO   = 0.15
TEST_RATIO  = 0.15


def get_transforms(mode: str = "train") -> transforms.Compose:
    """
    Retourne les transformations adaptées au mode.

    POURQUOI ces augmentations ?
    - RandomHorizontalFlip : une banane peut être filmée de gauche ou droite
      sur le convoyeur PHP → le modèle ne doit pas être sensible à l'orientation
    - RandomRotation(15°) : légère inclinaison possible sur le tapis
    - ColorJitter : simule les variations d'éclairage du pack-house
      (fluorescent en journée vs artificiel la nuit)
    - RandomResizedCrop : simule les bananes à différentes distances caméra
    ON N'UTILISE PAS : RandomVerticalFlip (une banane à l'envers n'existe pas
    sur un convoyeur), ni des rotations > 30° (irréaliste)

    Args:
        mode: "train" → augmentations actives | "val" ou "test" → aucune augmentation
    Returns:
        transforms.Compose : pipeline de transformations PyTorch
    """
    normalize = transforms.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)

    if mode == "train":
        return transforms.Compose([
            # Redimensionnement légèrement plus grand puis crop aléatoire
            # → simule zoom variable caméra convoyeur
            transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=15),
            transforms.ColorJitter(
                brightness=0.3,   # variations lumière pack-house PHP
                contrast=0.2,
                saturation=0.2,
                hue=0.05          # faible : on ne veut pas changer le vert en rouge
            ),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        # Val et test : aucune augmentation, juste redimensionner et normaliser
        # IMPORTANT : on utilise les mêmes stats ImageNet → cohérence avec pré-entraînement
        return transforms.Compose([
            transforms.Resize(256),          # légèrement plus grand
            transforms.CenterCrop(IMG_SIZE), # crop central → zone de fruit
            transforms.ToTensor(),
            normalize,
        ])



# NOUVELLE FONCTION 

def load_binary_dataset(data_dir, batch_size=32, num_workers=2):
    """
    Charge les données depuis trois sous-dossiers : train, val, test.
    Aucun split aléatoire n'est effectué.
    
    Args:
        data_dir : chemin vers le dossier parent (ex: './dataset/binary')
                   Ce dossier doit contenir train/, val/, test/
        batch_size : taille des lots
        num_workers : nombre de processus pour le chargement
        balance : (non utilisé ici car on gère le déséquilibre via pos_weight)
    Returns:
        train_loader, val_loader, test_loader, class_names
    """
    from pathlib import Path
    from torch.utils.data import DataLoader
    from torchvision import datasets
    
    data_dir = Path(data_dir)
    
    # Chemins des trois sous-dossiers
    train_dir = data_dir / "train"
    val_dir   = data_dir / "val"
    test_dir  = data_dir / "test"
    
    # Vérifie que les dossiers existent
    for d in [train_dir, val_dir, test_dir]:
        if not d.exists():
            raise FileNotFoundError(f"Dossier introuvable : {d}")
    
    # Création des datasets avec les transformations adaptées
    train_set = datasets.ImageFolder(train_dir, transform=get_transforms("train"))
    val_set   = datasets.ImageFolder(val_dir,   transform=get_transforms("val"))
    test_set  = datasets.ImageFolder(test_dir,  transform=get_transforms("test"))
    
    class_names = train_set.classes
    print(f"[Binary] Classes détectées : {class_names}")
    print(f"[Binary] Train : {len(train_set)} images")
    print(f"[Binary] Val   : {len(val_set)} images")
    print(f"[Binary] Test  : {len(test_set)} images")
    
    # Création des DataLoaders
    # train : shuffle=True pour mélanger les batches
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader   = DataLoader(val_set,   batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader  = DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)
    
    # Note : l'argument `balance` n'est pas utilisé ici.
    # L'équilibrage est déjà fait via pos_weight dans la loss (BCEWithLogitsLoss)
    # Si tu veux un WeightedRandomSampler sur train, il faudrait l'ajouter, mais ce n'est pas indispensable.
    
    return train_loader, val_loader, test_loader, class_names


def load_multiclass_dataset(data_dir, batch_size=32, num_workers=2):
    """
    Charge les données multi-classes depuis trois sous-dossiers : train, val, test.
    """
    data_dir = Path(data_dir)
    train_dir = data_dir / "train"
    val_dir   = data_dir / "valid"
    test_dir  = data_dir / "test"

    for d in [train_dir, val_dir, test_dir]:
        if not d.exists():
            raise FileNotFoundError(f"Dossier introuvable : {d}")

    train_set = datasets.ImageFolder(train_dir, transform=get_transforms("train"))
    val_set   = datasets.ImageFolder(val_dir,   transform=get_transforms("val"))
    test_set  = datasets.ImageFolder(test_dir,  transform=get_transforms("test"))

    class_names = train_set.classes
    print(f"[Multiclass] Classes : {class_names}")
    print(f"[Multiclass] Train : {len(train_set)}, Val : {len(val_set)}, Test : {len(test_set)}")

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader   = DataLoader(val_set,   batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader  = DataLoader(test_set,  batch_size=batch_size, shuffle=False, num_workers=num_workers)

    return train_loader, val_loader, test_loader, class_names

# %% [markdown]
# BananaVision — Module A : Script Principal
# PHP Plantations du Haut-Penja — UCAC-ICAM 2026
#
# USAGE (ligne de commande, comme exigé par le cahier des charges) :
#
#   # Classification binaire avec MobileNetV2
#   python run_module_a.py --task binary --arch mobilenet_v2 --data_dir ./dataset/binary
#
#   # Classification multi-classes avec EfficientNet-B0
#   python run_module_a.py --task multiclass --arch efficientnet_b0 --data_dir ./dataset/multiclass
#
#   # Comparer les deux architectures (pour le rapport)
#   python run_module_a.py --task binary --compare --data_dir ./dataset/binary
#
# Ce script est la démonstration LIVE exigée par le jury.
# L'étudiant responsable du Module A doit pouvoir :
#   1. Exécuter ce script en direct
#   2. Modifier batch_size, epochs, architecture à la demande du jury
#   3. Commenter chaque ligne à voix haute

# %% [markdown]
# BananaVision — Module A : Entraînement et Évaluation
# PHP Plantations du Haut-Penja — UCAC-ICAM 2026
#
# Ce module implémente :
#   - La boucle d'entraînement (train_one_epoch)
#   - L'évaluation complète avec toutes les métriques requises par le jury
#   - La génération de la matrice de confusion commentée en termes métier PHP
#   - La courbe ROC/AUC pour la tâche binaire
#   - La mesure du temps d'inférence par image (ms)
#
# MÉTRIQUES EXIGÉES PAR LE CAHIER DES CHARGES :
#   ✓ Précision, Rappel, F1-score par classe
#   ✓ Matrice de confusion commentée en termes métier PHP
#   ✓ Courbe ROC et AUC (tâche binaire uniquement)
#   ✓ Temps d'inférence moyen par image (ms)

# %%
import time
from pathlib import Path

import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("Agg")  # backend non-interactif pour serveur/Colab

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support,
    roc_curve,
    auc,
    ConfusionMatrixDisplay,
)


# ─────────────────────────────────────────────────────────────────
# BOUCLE D'ENTRAÎNEMENT
# ─────────────────────────────────────────────────────────────────

def train_one_epoch(
    model: nn.Module,
    loader: torch.utils.data.DataLoader,
    optimizer: torch.optim.Optimizer,
    criterion: nn.Module,
    device: torch.device,
    task: str = "binary",
) -> dict:
    """
    Exécute une epoch d'entraînement et retourne les métriques.

    CHOIX DE LA FONCTION DE PERTE :
    - Binaire  → BCEWithLogitsLoss
      Combine sigmoid + binary cross-entropy en une seule opération.
      Numériquement plus stable que d'appliquer sigmoid puis BCELoss.
      Permet de passer directement le logit brut (sortie de Linear).

    - Multi-classes → CrossEntropyLoss
      = LogSoftmax + NLLLoss. Calcule la perte pour N classes en une fois.
      Gère la normalisation softmax en interne → plus stable numériquement.

    Returns:
        dict avec "loss" et "accuracy" pour cette epoch
    """
    model.train()
    total_loss = 0.0
    correct    = 0
    total      = 0

    for images, labels in loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        if task == "binary":
            # outputs : [batch, 1] → squeeze → [batch]
            # labels  : [batch] entiers → float pour BCEWithLogitsLoss
            loss = criterion(outputs.squeeze(1), labels.float())
            preds = (torch.sigmoid(outputs.squeeze(1)) > 0.5).long()
        else: 
            loss = criterion(outputs, labels)
            preds = outputs.argmax(dim=1)
                        
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * images.size(0)
        correct    += (preds == labels).sum().item()
        total      += images.size(0)

    return {
        "loss": total_loss / total,
        "accuracy": correct / total,
    }


def evaluate(
    model: nn.Module,
    loader: torch.utils.data.DataLoader,
    criterion: nn.Module,
    device: torch.device,
    task: str = "binary",
    class_names: list[str] = None,
) -> dict:
    """
    Évalue le modèle sur un DataLoader (val ou test).
    Retourne toutes les métriques sans les afficher ni les sauvegarder.
    """
    model.eval()
    total_loss  = 0.0
    all_preds   = []
    all_labels  = []
    all_probs   = []  # pour la courbe ROC

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)

            if task == "binary":
                loss  = criterion(outputs.squeeze(1), labels.float())
                probs = torch.sigmoid(outputs.squeeze(1))
                preds = (probs > 0.5).long()
                all_probs.extend(probs.cpu().numpy())
            else: 
                loss = criterion(outputs, labels)
                preds = outputs.argmax(dim=1)
                probs = torch.softmax(outputs, dim=1)
                all_probs.extend(probs.cpu().numpy())

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            total_loss += loss.item() * images.size(0)

    n = len(all_labels)
    return {
        "loss"        : total_loss / n,
        "accuracy"    : np.mean(np.array(all_preds) == np.array(all_labels)),
        "all_preds"   : np.array(all_preds),
        "all_labels"  : np.array(all_labels),
        "all_probs"   : np.array(all_probs),
        "class_names" : class_names or [],
    }


# ─────────────────────────────────────────────────────────────────
# BOUCLE PRINCIPALE D'ENTRAÎNEMENT (PHASES 1 + 2)
# ─────────────────────────────────────────────────────────────────

def train_full(model, train_loader, val_loader, device, task, epochs_phase1, epochs_phase2, output_dir, architecture):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    # Choix de la fonction de perte
    if task == "binary":
        criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([2.0]).to(device))
        print("[Criterion] BCEWithLogitsLoss avec pos_weight=2.0")
    else:
        criterion = nn.CrossEntropyLoss()
        print("[Criterion] CrossEntropyLoss")

    history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
    best_val_loss = float("inf")
    patience_counter = 0
    PATIENCE = 5
    best_model_path = output_dir / f"best_{architecture}_{task}.pth"
    phase1_model_path = output_dir / f"best_{architecture}_{task}_phase1.pth"

    # ── PHASE 1 : Feature extraction ──────────────────────────────
    print(f"\n{'='*50}")
    print(f"PHASE 1 : Feature Extraction — {epochs_phase1} epochs")
    print(f"  Backbone gelé, seule la tête est entraînée")
    print(f"{'='*50}")

    # On gèle le backbone (déjà fait dans build_model avec freeze_backbone=True)
    # Mais on s'assure que le backbone est gelé
    for name, param in model.named_parameters():
        if "classifier" not in name:
            param.requires_grad = False

    optimizer = get_optimizer(model, phase=1)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)

    for epoch in range(1, epochs_phase1 + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion, device, task)
        val_metrics = evaluate(model, val_loader, criterion, device, task)

        scheduler.step(val_metrics["loss"])

        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["train_acc"].append(train_metrics["accuracy"])
        history["val_acc"].append(val_metrics["accuracy"])

        print(f"Epoch {epoch:02d}/{epochs_phase1} | "
              f"Train Loss: {train_metrics['loss']:.4f} Acc: {train_metrics['accuracy']:.3f} | "
              f"Val Loss: {val_metrics['loss']:.4f} Acc: {val_metrics['accuracy']:.3f}")

        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            torch.save(model.state_dict(), best_model_path)
            torch.save(model.state_dict(), phase1_model_path)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"  Early stopping déclenché à l'epoch {epoch}")
                break

    # ── TRANSITION : charger meilleur modèle phase 1 ───────────────
    print(f"\n[Transition] Chargement des meilleurs poids de la Phase 1...")
    model.load_state_dict(torch.load(phase1_model_path, map_location=device))

    # ── PHASE 2 : Fine-tuning ──────────────────────────────────────
    print(f"\n{'='*50}")
    print(f"PHASE 2 : Fine-tuning — {epochs_phase2} epochs")
    print(f"  Dernières couches backbone dégelées, lr réduit")
    print(f"{'='*50}")

    # Dégeler les dernières couches du backbone
    if architecture == "efficientnet_b0":
        _unfreeze_last_n_layers(model.features, n=3)
    elif architecture == "mobilenet_v2":
        _unfreeze_last_n_layers(model.features, n=5)

    optimizer = get_optimizer(model, phase=2)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)
    patience_counter = 0

    for epoch in range(1, epochs_phase2 + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion, device, task)
        val_metrics = evaluate(model, val_loader, criterion, device, task)

        scheduler.step(val_metrics["loss"])

        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["train_acc"].append(train_metrics["accuracy"])
        history["val_acc"].append(val_metrics["accuracy"])

        print(f"Epoch FT {epoch:02d}/{epochs_phase2} | "
              f"Train Loss: {train_metrics['loss']:.4f} Acc: {train_metrics['accuracy']:.3f} | "
              f"Val Loss: {val_metrics['loss']:.4f} Acc: {val_metrics['accuracy']:.3f}")

        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            torch.save(model.state_dict(), best_model_path)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"  Early stopping déclenché à l'epoch FT {epoch}")
                break

    # Charger le meilleur modèle final
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    print(f"\nMeilleur modèle chargé depuis {best_model_path}")

    return {"model": model, "history": history, "best_val_loss": best_val_loss}



    import os
    from pathlib import Path
    
    # SÉCURITÉ 1 : Création automatique du dossier de sortie s'il n'existe pas
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    
    # Définition de chemins clairs et distincts pour chaque phase
    phase1_model_path = output_path / f"best_{architecture}_{task}_phase1.pth"
    final_model_path = output_path / f"best_{architecture}_{task}.pth"
    
    # ==========================================
    # ── PHASE 1 : ENTRAÎNEMENT DU CLASSIFIEUR ──
    # ==========================================
    print(f"\n[Phase 1] Entraînement de la tête de classification ({epochs_phase1} époques)...")
    best_val_loss = float('inf')
    
    # ... (Ta boucle d'entraînement existante pour la Phase 1) ...
    # Exemple de structure de sauvegarde dans ta boucle :
    # if val_loss < best_val_loss:
    #     best_val_loss = val_loss
    #     torch.save(model.state_dict(), str(phase1_model_path))
    
    # Au cas où aucune sauvegarde n'a eu lieu dans la boucle, on assure une écriture :
    torch.save(model.state_dict(), str(phase1_model_path))
    print(f"✅ Fin Phase 1. Modèle intermédiaire sauvegardé sous : {phase1_model_path}")
    
    # ==========================================
    # ── TRANSITION : RECHARGEMENT DU MODÈLE ──
    # ==========================================
    print(f"\n[Transition] Chargement des meilleurs poids de la Phase 1...")
    if not phase1_model_path.exists():
        raise FileNotFoundError(f"Impossible de trouver le fichier de la Phase 1 à l'emplacement : {phase1_model_path}")
        
    model.load_state_dict(torch.load(str(phase1_model_path), map_location=device))
    
    # ==========================================
    # ── PHASE 2 : FINE-TUNING GLOBAL ──────────
    # ==========================================
    print(f"\n[Phase 2] Dégel partiel/total du backbone et fine-tuning ({epochs_phase2} époques)...")
    
    # Logique pour dégeler le backbone (déjà présente dans ton code de Cell 6)
    if architecture == "efficientnet_b0":
        # Dégeler par exemple les derniers blocs de features
        for param in model.features[-2:].parameters():
            param.requires_grad = True
    elif architecture == "mobilenet_v2":
        for param in model.features[-4:].parameters():
            param.requires_grad = True
            
    # ... (Ta boucle d'entraînement existante pour la Phase 2) ...
    
    # Sauvegarde définitive du modèle pour ton application Gradio
    torch.save(model.state_dict(), str(final_model_path))
    print(f"🏆 Entraînement complet terminé ! Modèle final disponible sous : {final_model_path}")
    
    return {"model": model, "path": final_model_path}
# ─────────────────────────────────────────────────────────────────
# MÉTRIQUES ET VISUALISATIONS (exigées par le cahier des charges)
# ─────────────────────────────────────────────────────────────────

def compute_inference_time(model: nn.Module, device: torch.device, n_runs: int = 100) -> float:
    """
    Mesure le temps d'inférence moyen par image en millisecondes.

    PERTINENCE POUR PHP : le tapis convoyeur traite 3-4 mains par minute.
    Une main = ~12-15 doigts. Soit ~1 image toutes les 1-2 secondes maximum.
    Le modèle doit inférer en < 200ms pour ne pas bloquer le convoyeur.
    MobileNetV2 (~30ms) et EfficientNet-B0 (~50ms) sont largement compatibles.
    """
    model.eval()
    dummy_input = torch.randn(1, 3, 224, 224).to(device)

    # Warm-up : les premières passes sont lentes (allocations mémoire GPU)
    with torch.no_grad():
        for _ in range(10):
            _ = model(dummy_input)

    # Mesure réelle
    times = []
    with torch.no_grad():
        for _ in range(n_runs):
            start = time.perf_counter()
            _ = model(dummy_input)
            if device.type == "cuda":
                torch.cuda.synchronize()  # attendre la fin GPU
            end = time.perf_counter()
            times.append((end - start) * 1000)  # en ms

    mean_ms = np.mean(times)
    std_ms  = np.std(times)
    print(f"\n[Inference Time] {mean_ms:.2f} ± {std_ms:.2f} ms/image")
    print(f"  → Compatible convoyeur PHP : {'OUI' if mean_ms < 200 else 'NON (> 200ms)'}")
    return mean_ms


def plot_confusion_matrix_php(
    all_labels: np.ndarray,
    all_preds: np.ndarray,
    class_names: list[str],
    task: str,
    save_path: str = None,
) -> None:
    """
    Génère et sauvegarde la matrice de confusion avec commentaire métier PHP.

    LECTURE DE LA MATRICE POUR LE JURY PHP :
    Pour la tâche BINAIRE (export=0, rejeté=1) :

    Matrice :         Prédit Export  Prédit Rejeté
    Réel Export   [[      TP,              FP      ]]
    Réel Rejeté   [[      FN,              TN      ]]

    ⚠ FN (Faux Négatif) = banane rejetée classée "export"
      → C'est la pire erreur pour PHP : risque de rejet de conteneur en Europe
      → Justifie pos_weight=2.0 dans BCEWithLogitsLoss

    ⚠ FP (Faux Positif) = bonne banane classée "rejetée"
      → Perte de revenu mais pas de risque client
      → Moins grave, mais à minimiser aussi pour la rentabilité
    """
    cm = confusion_matrix(all_labels, all_preds)

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Matrice brute (valeurs absolues)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(ax=axes[0], colorbar=False, cmap="Blues")
    axes[0].set_title("Matrice de confusion — valeurs absolues")

    # Matrice normalisée (pourcentages)
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=class_names)
    disp_norm.plot(ax=axes[1], colorbar=False, cmap="Blues",
                   values_format=".1%")
    axes[1].set_title("Matrice de confusion — taux normalisés")

    # Annotation métier PHP pour la tâche binaire
    if task == "binary" and len(class_names) == 2:
        tn, fp, fn, tp = cm.ravel()
        php_comment = (
            f"Analyse métier PHP :\n"
            f"  ✓ Bananes export correctement acceptées (TP) : {tp}\n"
            f"  ✗ Bananes rejetées acceptées par erreur (FN) : {fn}  ← CRITIQUE\n"
            f"    → Risque rejet conteneur Europe\n"
            f"  ! Bonnes bananes rejetées par erreur (FP)     : {fp}\n"
            f"    → Perte de revenu estimée : {fp * 0.45:.0f} € (à 0.45€/banane)"
        )
        fig.text(0.5, -0.05, php_comment, ha="center", fontsize=9,
                 bbox=dict(boxstyle="round", facecolor="lightyellow", alpha=0.8))

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        print(f"[Confusion Matrix] Sauvegardée : {save_path}")
    plt.close()


def plot_roc_curve(
    all_labels: np.ndarray,
    all_probs: np.ndarray,
    save_path: str = None,
) -> float:
    """
    Trace et sauvegarde la courbe ROC avec l'AUC.

    INTERPRÉTATION POUR LE JURY :
    AUC (Aire Sous la Courbe) mesure la capacité du modèle à discriminer
    les deux classes indépendamment du seuil choisi.

    AUC = 0.5 → modèle aléatoire (inutile)
    AUC = 0.7 → acceptable
    AUC = 0.9 → très bon
    AUC = 1.0 → parfait (suspect : probablement du data leakage)

    LIEN AVEC LE MDP (Module C) :
    La courbe ROC permet de choisir le seuil de décision optimal en
    fonction des coûts métier PHP (coût FN vs coût FP) → ce seuil
    sera intégré comme paramètre dans le MDP du Module C.
    """
    fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
    roc_auc = auc(fpr, tpr)

    # Point de fonctionnement optimal : maximise TPR - FPR (index de Youden)
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]
    optimal_fpr = fpr[optimal_idx]
    optimal_tpr = tpr[optimal_idx]

    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(fpr, tpr, color="steelblue", lw=2,
            label=f"Courbe ROC (AUC = {roc_auc:.3f})")
    ax.plot([0, 1], [0, 1], "k--", lw=1, label="Modèle aléatoire (AUC = 0.5)")
    ax.scatter(optimal_fpr, optimal_tpr, color="red", s=80, zorder=5,
               label=f"Seuil optimal = {optimal_threshold:.2f}")

    ax.set_xlabel("Taux de Faux Positifs (FPR)")
    ax.set_ylabel("Taux de Vrais Positifs (TPR = Rappel)")
    ax.set_title("Courbe ROC — Classification Binaire BananaVision\n"
                 f"(export vs rejeté) — AUC = {roc_auc:.3f}")
    ax.legend(loc="lower right")
    ax.grid(True, alpha=0.3)

    ax.annotate(
        f"Seuil optimal PHP = {optimal_threshold:.2f}\n"
        f"TPR = {optimal_tpr:.1%} | FPR = {optimal_fpr:.1%}",
        xy=(optimal_fpr, optimal_tpr), xytext=(0.4, 0.3),
        arrowprops=dict(arrowstyle="->", color="red"),
        fontsize=9, color="red",
    )

    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        print(f"[ROC Curve] Sauvegardée : {save_path}")
    plt.close()

    print(f"\n[AUC] {roc_auc:.4f}")
    print(f"[Seuil optimal] {optimal_threshold:.2f} "
          f"(TPR={optimal_tpr:.3f}, FPR={optimal_fpr:.3f})")
    return roc_auc


def print_classification_report_php(
    all_labels: np.ndarray,
    all_preds: np.ndarray,
    class_names: list[str],
    task: str,
) -> None:
    """
    Affiche le rapport de classification avec commentaires métier PHP.
    """
    print("\n" + "="*60)
    print(f"RAPPORT DE CLASSIFICATION — {task.upper()}")
    print("="*60)
    print(classification_report(all_labels, all_preds, target_names=class_names))

    if task == "binary":
        print("INTERPRÉTATION MÉTIER PHP :")
        print("  Précision 'rejeté' : parmi les fruits classés rejetés, combien le sont vraiment ?")
        print("    → Une faible précision = beaucoup de bonnes bananes rejetées (perte de revenu)")
        print("  Rappel 'rejeté'    : parmi les fruits vraiment rejetés, combien sont détectés ?")
        print("    → Un faible rappel = des fruits non-conformes acceptés (risque client Europe)")
        print("  F1-score = équilibre entre précision et rappel")
        print("  Pour PHP : prioriser le RAPPEL sur 'rejeté' (éviter les FN critiques)")

    #if task == "multiclass":
    # Convertir les prédictions et labels (one-hot -> indices pour le rapport)
    # Pour chaque classe, on calcule les métriques binaires
       # from sklearn.metrics import precision_recall_fscore_support
        #print("\n" + "="*60)
        #print("RAPPORT MULTI-LABEL (par défaut)")
        #print("="*60)

        #for i, name in enumerate(class_names):
            #y_true = all_labels[:, i] if all_labels.ndim > 1 else (all_labels == i).astype(int)
            #y_pred = all_preds[:, i]
            #p, r, f, _ = precision_recall_fscore_support(y_true, y_pred, average='binary')
            #print(f"{name:20}   précision={p:.3f}   rappel={r:.3f}   f1={f:.3f}")

# %%
import argparse
import time
from pathlib import Path
import sys
import os
import torch
import torch.nn as nn
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay

# ------------------- Définition des fonctions nécessaires -------------------
def get_transforms(mode="train"):
    IMG_SIZE = 224
    IMAGENET_MEAN = [0.485, 0.456, 0.406]
    IMAGENET_STD = [0.229, 0.224, 0.225]
    normalize = transforms.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)
    if mode == "train":
        return transforms.Compose([
            transforms.RandomResizedCrop(IMG_SIZE, scale=(0.8, 1.0)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(degrees=15),
            transforms.ColorJitter(brightness=0.3, contrast=0.2, saturation=0.2, hue=0.05),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        return transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(IMG_SIZE),
            transforms.ToTensor(),
            normalize,
        ])

def load_binary_dataset(data_dir, batch_size=32, num_workers=2):
    data_dir = Path(data_dir)
    train_dir = data_dir / "train"
    val_dir = data_dir / "val"
    test_dir = data_dir / "test"
    for d in [train_dir, val_dir, test_dir]:
        if not d.exists():
            raise FileNotFoundError(f"Dossier introuvable : {d}")
    train_set = datasets.ImageFolder(train_dir, transform=get_transforms("train"))
    val_set = datasets.ImageFolder(val_dir, transform=get_transforms("val"))
    test_set = datasets.ImageFolder(test_dir, transform=get_transforms("test"))
    class_names = train_set.classes
    print(f"[Binary] Classes : {class_names}")
    print(f"[Binary] Train: {len(train_set)}, Val: {len(val_set)}, Test: {len(test_set)}")
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return train_loader, val_loader, test_loader, class_names

def load_multiclass_dataset(data_dir, batch_size=32, num_workers=2):
    data_dir = Path(data_dir)
    train_dir = data_dir / "train"
    val_dir = data_dir / "valid"
    test_dir = data_dir / "test"
    for d in [train_dir, val_dir, test_dir]:
        if not d.exists():
            raise FileNotFoundError(f"Dossier introuvable : {d}")
    train_set = datasets.ImageFolder(train_dir, transform=get_transforms("train"))
    val_set = datasets.ImageFolder(val_dir, transform=get_transforms("val"))
    test_set = datasets.ImageFolder(test_dir, transform=get_transforms("test"))
    class_names = train_set.classes
    print(f"[Multiclass] Classes : {class_names}")
    print(f"[Multiclass] Train: {len(train_set)}, Val: {len(val_set)}, Test: {len(test_set)}")
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return train_loader, val_loader, test_loader, class_names

def _build_head(in_features, num_classes, task):
    if task == "binary":
        return nn.Sequential(
            nn.Dropout(p=0.3),
            nn.Linear(in_features, 256),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(256, 1)
        )
    else:
        return nn.Sequential(
            nn.Dropout(p=0.3),
            nn.Linear(in_features, 256),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(256, num_classes)
        )

def _unfreeze_last_n_layers(feature_extractor, n):
    layers = list(feature_extractor.children())
    for layer in layers[-n:]:
        for param in layer.parameters():
            param.requires_grad = True

def _print_trainable_params(model, name):
    total = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"[{name}] Params total: {total:,} | Entraînables: {trainable:,} ({100*trainable/total:.1f}%)")

def build_model(architecture, num_classes, task="binary", freeze_backbone=True):
    if architecture == "mobilenet_v2":
        weights = models.MobileNet_V2_Weights.IMAGENET1K_V1
        model = models.mobilenet_v2(weights=weights)
        in_features = model.classifier[1].in_features
        if freeze_backbone:
            for param in model.parameters():
                param.requires_grad = False
        else:
            _unfreeze_last_n_layers(model.features, n=5)
        model.classifier = _build_head(in_features, num_classes, task)
        _print_trainable_params(model, "MobileNetV2")
    elif architecture == "efficientnet_b0":
        weights = models.EfficientNet_B0_Weights.IMAGENET1K_V1
        model = models.efficientnet_b0(weights=weights)
        in_features = model.classifier[1].in_features
        if freeze_backbone:
            for param in model.parameters():
                param.requires_grad = False
        else:
            _unfreeze_last_n_layers(model.features, n=3)
        model.classifier = _build_head(in_features, num_classes, task)
        _print_trainable_params(model, "EfficientNet-B0")
    else:
        raise ValueError(f"Architecture inconnue : {architecture}")
    return model

def get_optimizer(model, phase=1):
    if phase == 1:
        params = filter(lambda p: p.requires_grad, model.parameters())
        return torch.optim.Adam(params, lr=1e-3, weight_decay=1e-4)
    else:
        backbone_params = []
        head_params = []
        for name, param in model.named_parameters():
            if param.requires_grad:
                if "classifier" in name:
                    head_params.append(param)
                else:
                    backbone_params.append(param)
        return torch.optim.Adam([
            {"params": backbone_params, "lr": 1e-5},
            {"params": head_params, "lr": 1e-4},
        ], weight_decay=1e-4)

def train_one_epoch(model, loader, optimizer, criterion, device, task="binary"):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        if task == "binary":
            loss = criterion(outputs.squeeze(1), labels.float())
            preds = (torch.sigmoid(outputs.squeeze(1)) > 0.5).long()
        else:
            loss = criterion(outputs, labels)
            preds = outputs.argmax(dim=1)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * images.size(0)
        correct += (preds == labels).sum().item()
        total += images.size(0)
    return {"loss": total_loss / total, "accuracy": correct / total}

def evaluate(model, loader, criterion, device, task="binary", class_names=None):
    model.eval()
    total_loss = 0.0
    all_preds, all_labels, all_probs = [], [], []
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            if task == "binary":
                loss = criterion(outputs.squeeze(1), labels.float())
                probs = torch.sigmoid(outputs.squeeze(1))
                preds = (probs > 0.5).long()
                all_probs.extend(probs.cpu().numpy())
            else:
                loss = criterion(outputs, labels)
                preds = outputs.argmax(dim=1)
                probs = torch.softmax(outputs, dim=1)
                all_probs.extend(probs.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_loss += loss.item() * images.size(0)
    n = len(all_labels)
    return {
        "loss": total_loss / n,
        "accuracy": np.mean(np.array(all_preds) == np.array(all_labels)),
        "all_preds": np.array(all_preds),
        "all_labels": np.array(all_labels),
        "all_probs": np.array(all_probs),
        "class_names": class_names or []
    }

def train_full(model, train_loader, val_loader, device, task, epochs_phase1, epochs_phase2, output_dir, architecture):
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    if task == "binary":
        criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([2.0]).to(device))
        print("[Criterion] BCEWithLogitsLoss avec pos_weight=2.0")
    else:
        criterion = nn.CrossEntropyLoss()
        print("[Criterion] CrossEntropyLoss")

    history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
    best_val_loss = float("inf")
    patience_counter = 0
    PATIENCE = 5
    best_model_path = output_dir / f"best_{architecture}_{task}.pth"
    phase1_model_path = output_dir / f"best_{architecture}_{task}_phase1.pth"

    # Phase 1
    print(f"\n{'='*50}")
    print(f"PHASE 1 : Feature Extraction — {epochs_phase1} epochs")
    print(f"{'='*50}")
    # Assurer que le backbone est gelé (déjà fait par freeze_backbone=True, mais on renforce)
    for name, param in model.named_parameters():
        if "classifier" not in name:
            param.requires_grad = False
    optimizer = get_optimizer(model, phase=1)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)

    for epoch in range(1, epochs_phase1 + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion, device, task)
        val_metrics = evaluate(model, val_loader, criterion, device, task)
        scheduler.step(val_metrics["loss"])
        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["train_acc"].append(train_metrics["accuracy"])
        history["val_acc"].append(val_metrics["accuracy"])
        print(f"Epoch {epoch:02d}/{epochs_phase1} | Train Loss: {train_metrics['loss']:.4f} Acc: {train_metrics['accuracy']:.3f} | Val Loss: {val_metrics['loss']:.4f} Acc: {val_metrics['accuracy']:.3f}")
        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            torch.save(model.state_dict(), best_model_path)
            torch.save(model.state_dict(), phase1_model_path)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"  Early stopping at epoch {epoch}")
                break

    # Transition : charger le meilleur modèle de phase 1
    model.load_state_dict(torch.load(phase1_model_path, map_location=device))

    # Phase 2
    print(f"\n{'='*50}")
    print(f"PHASE 2 : Fine-tuning — {epochs_phase2} epochs")
    print(f"{'='*50}")
    if architecture == "efficientnet_b0":
        _unfreeze_last_n_layers(model.features, n=3)
    elif architecture == "mobilenet_v2":
        _unfreeze_last_n_layers(model.features, n=5)
    optimizer = get_optimizer(model, phase=2)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)
    patience_counter = 0

    for epoch in range(1, epochs_phase2 + 1):
        train_metrics = train_one_epoch(model, train_loader, optimizer, criterion, device, task)
        val_metrics = evaluate(model, val_loader, criterion, device, task)
        scheduler.step(val_metrics["loss"])
        history["train_loss"].append(train_metrics["loss"])
        history["val_loss"].append(val_metrics["loss"])
        history["train_acc"].append(train_metrics["accuracy"])
        history["val_acc"].append(val_metrics["accuracy"])
        print(f"Epoch FT {epoch:02d}/{epochs_phase2} | Train Loss: {train_metrics['loss']:.4f} Acc: {train_metrics['accuracy']:.3f} | Val Loss: {val_metrics['loss']:.4f} Acc: {val_metrics['accuracy']:.3f}")
        if val_metrics["loss"] < best_val_loss:
            best_val_loss = val_metrics["loss"]
            torch.save(model.state_dict(), best_model_path)
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= PATIENCE:
                print(f"  Early stopping at epoch FT {epoch}")
                break

    model.load_state_dict(torch.load(best_model_path, map_location=device))
    print(f"\nMeilleur modèle chargé depuis {best_model_path}")
    return {"model": model, "history": history, "best_val_loss": best_val_loss}

def compute_inference_time(model, device, n_runs=100):
    model.eval()
    dummy_input = torch.randn(1, 3, 224, 224).to(device)
    with torch.no_grad():
        for _ in range(10):
            _ = model(dummy_input)
    times = []
    with torch.no_grad():
        for _ in range(n_runs):
            start = time.perf_counter()
            _ = model(dummy_input)
            if device.type == "cuda":
                torch.cuda.synchronize()
            end = time.perf_counter()
            times.append((end - start) * 1000)
    mean_ms = np.mean(times)
    std_ms = np.std(times)
    print(f"\n[Inference Time] {mean_ms:.2f} ± {std_ms:.2f} ms/image")
    print(f"  → Compatible convoyeur PHP : {'OUI' if mean_ms < 200 else 'NON (> 200ms)'}")
    return mean_ms

def plot_confusion_matrix_php(all_labels, all_preds, class_names, task, save_path=None):
    cm = confusion_matrix(all_labels, all_preds)
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(ax=axes[0], colorbar=False, cmap="Blues")
    axes[0].set_title("Matrice de confusion — valeurs absolues")
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)
    disp_norm = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=class_names)
    disp_norm.plot(ax=axes[1], colorbar=False, cmap="Blues", values_format=".1%")
    axes[1].set_title("Matrice de confusion — taux normalisés")
    if task == "binary" and len(class_names) == 2:
        tn, fp, fn, tp = cm.ravel()
        php_comment = (f"Analyse métier PHP :\n  ✓ Bananes export correctement acceptées (TP) : {tp}\n  ✗ Bananes rejetées acceptées par erreur (FN) : {fn}  ← CRITIQUE\n    → Risque rejet conteneur Europe\n  ! Bonnes bananes rejetées par erreur (FP)     : {fp}\n    → Perte de revenu estimée : {fp * 0.45:.0f} € (à 0.45€/banane)")
        fig.text(0.5, -0.05, php_comment, ha="center", fontsize=9, bbox=dict(boxstyle="round", facecolor="lightyellow", alpha=0.8))
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        print(f"[Confusion Matrix] Sauvegardée : {save_path}")
    plt.close()

def plot_roc_curve(all_labels, all_probs, save_path=None):
    fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
    roc_auc = auc(fpr, tpr)
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]
    optimal_fpr = fpr[optimal_idx]
    optimal_tpr = tpr[optimal_idx]
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.plot(fpr, tpr, color="steelblue", lw=2, label=f"Courbe ROC (AUC = {roc_auc:.3f})")
    ax.plot([0, 1], [0, 1], "k--", lw=1, label="Modèle aléatoire (AUC = 0.5)")
    ax.scatter(optimal_fpr, optimal_tpr, color="red", s=80, zorder=5, label=f"Seuil optimal = {optimal_threshold:.2f}")
    ax.set_xlabel("Taux de Faux Positifs (FPR)")
    ax.set_ylabel("Taux de Vrais Positifs (TPR = Rappel)")
    ax.set_title("Courbe ROC — Classification Binaire BananaVision")
    ax.legend(loc="lower right")
    ax.grid(True, alpha=0.3)
    ax.annotate(f"Seuil optimal PHP = {optimal_threshold:.2f}\nTPR = {optimal_tpr:.1%} | FPR = {optimal_fpr:.1%}", xy=(optimal_fpr, optimal_tpr), xytext=(0.4, 0.3), arrowprops=dict(arrowstyle="->", color="red"), fontsize=9, color="red")
    if save_path:
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        print(f"[ROC Curve] Sauvegardée : {save_path}")
    plt.close()
    print(f"\n[AUC] {roc_auc:.4f}")
    print(f"[Seuil optimal] {optimal_threshold:.2f} (TPR={optimal_tpr:.3f}, FPR={optimal_fpr:.3f})")
    return roc_auc

def print_classification_report_php(all_labels, all_preds, class_names, task):
    print("\n" + "="*60)
    print(f"RAPPORT DE CLASSIFICATION — {task.upper()}")
    print("="*60)
    print(classification_report(all_labels, all_preds, target_names=class_names))
    if task == "binary":
        print("INTERPRÉTATION MÉTIER PHP :")
        print("  Précision 'rejeté' : parmi les fruits classés rejetés, combien le sont vraiment ?")
        print("    → Une faible précision = beaucoup de bonnes bananes rejetées (perte de revenu)")
        print("  Rappel 'rejeté'    : parmi les fruits vraiment rejetés, combien sont détectés ?")
        print("    → Un faible rappel = des fruits non-conformes acceptés (risque client Europe)")
        print("  F1-score = équilibre entre précision et rappel")
        print("  Pour PHP : prioriser le RAPPEL sur 'rejeté' (éviter les FN critiques)")

# ------------------- Fonctions pour les expériences -------------------
def parse_args():
    parser = argparse.ArgumentParser(description="BananaVision — Module A CNN")
    parser.add_argument("--task", choices=["binary", "multiclass"], required=True)
    parser.add_argument("--arch", choices=["mobilenet_v2", "efficientnet_b0"], default="efficientnet_b0")
    parser.add_argument("--data_dir", type=str, required=True, help="Chemin vers le dossier du dataset")
    parser.add_argument("--batch_size", type=int, default=32)
    parser.add_argument("--epochs_phase1", type=int, default=10)
    parser.add_argument("--epochs_phase2", type=int, default=10)
    parser.add_argument("--output_dir", type=str, default="outputs/module_a")
    parser.add_argument("--compare", action="store_true", help="Compare MobileNetV2 vs EfficientNet-B0")
    return parser.parse_args()

def run_single_experiment(args, architecture: str) -> dict:
    print(f"\n{'#'*60}")
    print(f"# EXPÉRIENCE : {architecture.upper()} — Tâche : {args.task.upper()}")
    print(f"{'#'*60}")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"\n[Device] Utilisation de : {device}")
    if device.type == "cuda":
        print(f"  GPU : {torch.cuda.get_device_name(0)}")
        print(f"  VRAM disponible : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    print(f"\n[Data] Chargement depuis {args.data_dir}")
    if args.task == "binary":
        train_loader, val_loader, test_loader, class_names = load_binary_dataset(args.data_dir, batch_size=args.batch_size)
    else:
        train_loader, val_loader, test_loader, class_names = load_multiclass_dataset(args.data_dir, batch_size=args.batch_size)
    num_classes = 1 if args.task == "binary" else len(class_names)
    print(f"\n[Model] Chargement {architecture} pré-entraîné (ImageNet)")
    model = build_model(architecture=architecture, num_classes=num_classes, task=args.task, freeze_backbone=True).to(device)
    print(f"\n[Training] Démarrage de l'entraînement en 2 phases")
    result = train_full(model, train_loader, val_loader, device, args.task, args.epochs_phase1, args.epochs_phase2, args.output_dir, architecture)
    model = result["model"]
    print(f"\n[Evaluation] Test set — données jamais vues pendant l'entraînement")
    if args.task == "binary":
        criterion = nn.BCEWithLogitsLoss(pos_weight=torch.tensor([2.0]).to(device))
    else:
        criterion = nn.CrossEntropyLoss()
    test_metrics = evaluate(model, test_loader, criterion, device, args.task, class_names)
    print_classification_report_php(test_metrics["all_labels"], test_metrics["all_preds"], class_names, args.task)
    output_dir = Path(args.output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    cm_path = output_dir / f"confusion_matrix_{architecture}_{args.task}.png"
    plot_confusion_matrix_php(test_metrics["all_labels"], test_metrics["all_preds"], class_names, args.task, save_path=str(cm_path))
    roc_auc = None
    if args.task == "binary":
        roc_path = output_dir / f"roc_curve_{architecture}.png"
        roc_auc = plot_roc_curve(test_metrics["all_labels"], test_metrics["all_probs"], save_path=str(roc_path))
    inference_ms = compute_inference_time(model, device)
    summary = {"architecture": architecture, "task": args.task, "test_accuracy": test_metrics["accuracy"], "auc": roc_auc, "inference_ms": inference_ms}
    print(f"\n{'='*50}")
    print(f"RÉSUMÉ FINAL — {architecture}")
    print(f"{'='*50}")
    print(f"  Accuracy (test)  : {test_metrics['accuracy']:.3f}")
    if roc_auc:
        print(f"  AUC (test)       : {roc_auc:.3f}")
    print(f"  Inference time   : {inference_ms:.1f} ms/image")
    print(f"  Figures sauvées  : {output_dir}/")
    return summary

def compare_architectures(args) -> None:
    results = {}
    for arch in ["mobilenet_v2", "efficientnet_b0"]:
        results[arch] = run_single_experiment(args, arch)
    print(f"\n{'='*60}")
    print("TABLEAU COMPARATIF — MobileNetV2 vs EfficientNet-B0")
    print(f"{'='*60}")
    print(f"{'Métrique':<25} {'MobileNetV2':>15} {'EfficientNet-B0':>18}")
    print("-"*60)
    metrics_labels = {"test_accuracy": "Accuracy (test)", "auc": "AUC ROC", "inference_ms": "Temps inférence (ms)"}
    for key, label in metrics_labels.items():
        v1 = results["mobilenet_v2"][key]
        v2 = results["efficientnet_b0"][key]
        if v1 is not None and v2 is not None:
            if key == "inference_ms":
                better = "MobileNetV2" if v1 < v2 else "EfficientNet-B0"
                print(f"{label:<25} {v1:>14.1f}ms {v2:>17.1f}ms  ← {better} plus rapide")
            else:
                better = "MobileNetV2" if v1 > v2 else "EfficientNet-B0"
                print(f"{label:<25} {v1:>15.4f} {v2:>18.4f}  ← {better} meilleur")
    print(f"\nRECOMMANDATION POUR LE RAPPORT :")
    m1 = results["mobilenet_v2"]
    m2 = results["efficientnet_b0"]
    if m1["test_accuracy"] is not None and m2["test_accuracy"] is not None:
        diff_acc = abs(m1["test_accuracy"] - m2["test_accuracy"])
        if diff_acc < 0.03:
            print(f"  Les deux architectures ont des performances similaires (Δ={diff_acc:.1%}).")
            print(f"  Choisir MobileNetV2 pour le déploiement temps réel sur convoyeur PHP.")
        elif m2["test_accuracy"] > m1["test_accuracy"]:
            print(f"  EfficientNet-B0 est significativement meilleur (+{diff_acc:.1%}).")
            print(f"  Justifier le coût en inférence vs gain de précision dans le rapport.")

if __name__ == "__main__":
    original_argv = sys.argv
    try:
        sys.argv = ['run_module_a.py', '--task', 'binary', '--data_dir', './dataset/binary']
        args = parse_args()
        if args.compare:
            compare_architectures(args)
        else:
            run_single_experiment(args, args.arch)
    finally:
        sys.argv = original_argv
# Out:
# ############################################################
# # EXPÉRIENCE : EFFICIENTNET_B0 — Tâche : BINARY
# ############################################################
#
# [Device] Utilisation de : cuda
#   GPU : NVIDIA GeForce RTX 3050 6GB Laptop GPU
#   VRAM disponible : 6.4 GB
#
# [Data] Chargement depuis ./dataset/binary
# [Binary] Classes : ['bananes_export', 'bananes_rejetees']
# [Binary] Train: 11793, Val: 1123, Test: 562
#
# [Model] Chargement efficientnet_b0 pré-entraîné (ImageNet)
# [EfficientNet-B0] Params total: 4,335,741 | Entraînables: 328,193 (7.6%)
#
# [Training] Démarrage de l'entraînement en 2 phases
# [Criterion] BCEWithLogitsLoss avec pos_weight=2.0
#
# ==================================================
# PHASE 1 : Feature Extraction — 10 epochs
# ==================================================
# Epoch 01/10 | Train Loss: 0.1287 Acc: 0.963 | Val Loss: 0.0411 Acc: 0.992
# Epoch 02/10 | Train Loss: 0.0674 Acc: 0.982 | Val Loss: 0.0249 Acc: 0.988
# Epoch 03/10 | Train Loss: 0.0557 Acc: 0.984 | Val Loss: 0.0304 Acc: 0.994
# Epoch 04/10 | Train Loss: 0.0505 Acc: 0.985 | Val Loss: 0.0264 Acc: 0.994
# Epoch 05/10 | Train Loss: 0.0444 Acc: 0.988 | Val Loss: 0.0206 Acc: 0.993
# Epoch 06/10 | Train Loss: 0.0415 Acc: 0.988 | Val Loss: 0.0203 Acc: 0.992
# Epoch 07/10 | Train Loss: 0.0405 Acc: 0.988 | Val Loss: 0.0200 Acc: 0.996
# Epoch 08/10 | Train Loss: 0.0419 Acc: 0.988 | Val Loss: 0.0200 Acc: 0.995
# Epoch 09/10 | Train Loss: 0.0456 Acc: 0.988 | Val Loss: 0.0226 Acc: 0.994
# Epoch 10/10 | Train Loss: 0.0334 Acc: 0.990 | Val Loss: 0.0203 Acc: 0.995
#
# ==================================================
# PHASE 2 : Fine-tuning — 10 epochs
# ==================================================
# Epoch FT 01/10 | Train Loss: 0.0321 Acc: 0.991 | Val Loss: 0.0194 Acc: 0.996
# Epoch FT 02/10 | Train Loss: 0.0243 Acc: 0.993 | Val Loss: 0.0212 Acc: 0.996
# Epoch FT 03/10 | Train Loss: 0.0252 Acc: 0.994 | Val Loss: 0.0244 Acc: 0.996
# Epoch FT 04/10 | Train Loss: 0.0227 Acc: 0.994 | Val Loss: 0.0243 Acc: 0.996
# Epoch FT 05/10 | Train Loss: 0.0207 Acc: 0.994 | Val Loss: 0.0242 Acc: 0.996
# Epoch FT 06/10 | Train Loss: 0.0180 Acc: 0.994 | Val Loss: 0.0255 Acc: 0.996
#   Early stopping at epoch FT 6
#
# Meilleur modèle chargé depuis outputs\module_a\best_efficientnet_b0_binary.pth
#
# [Evaluation] Test set — données jamais vues pendant l'entraînement
#
# ============================================================
# RAPPORT DE CLASSIFICATION — BINARY
# ============================================================
#                   precision    recall  f1-score   support
#
#   bananes_export       0.99      0.96      0.98       110
# bananes_rejetees       0.99      1.00      0.99       452
#
#         accuracy                           0.99       562
#        macro avg       0.99      0.98      0.99       562
#     weighted avg       0.99      0.99      0.99       562
#
# INTERPRÉTATION MÉTIER PHP :
#   Précision 'rejeté' : parmi les fruits classés rejetés, combien le sont vraiment ?
#     → Une faible précision = beaucoup de bonnes bananes rejetées (perte de revenu)
#   Rappel 'rejeté'    : parmi les fruits vraiment rejetés, combien sont détectés ?
#     → Un faible rappel = des fruits non-conformes acceptés (risque client Europe)
#   F1-score = équilibre entre précision et rappel
#   Pour PHP : prioriser le RAPPEL sur 'rejeté' (éviter les FN critiques)
# [Confusion Matrix] Sauvegardée : outputs\module_a\confusion_matrix_efficientnet_b0_binary.png
# [ROC Curve] Sauvegardée : outputs\module_a\roc_curve_efficientnet_b0.png
#
# [AUC] 0.9994
# [Seuil optimal] 0.64 (TPR=0.998, FPR=0.009)
#
# [Inference Time] 10.34 ± 2.24 ms/image
#   → Compatible convoyeur PHP : OUI
#
# ==================================================
# RÉSUMÉ FINAL — efficientnet_b0
# ==================================================
#   Accuracy (test)  : 0.991
#   AUC (test)       : 0.999
#   Inference time   : 10.3 ms/image
#   Figures sauvées  : outputs\module_a/

# %%
# Entraînement du modèle multi-classes (défauts)
print("\n" + "="*60)
print("Lancement de l'entraînement multi-classes (EfficientNet-B0)")
print("="*60)

# Sauvegarde des arguments système pour ne pas tout casser
import sys
original_argv = sys.argv.copy()

try:
    sys.argv = ['run_module_a.py', '--task', 'multiclass', '--data_dir', './dataset/multiclass', '--arch', 'efficientnet_b0']
    args = parse_args()
    run_single_experiment(args, args.arch)
finally:
    sys.argv = original_argv
# Out:
# ============================================================
# Lancement de l'entraînement multi-classes (EfficientNet-B0)
# ============================================================
#
# ############################################################
# # EXPÉRIENCE : EFFICIENTNET_B0 — Tâche : MULTICLASS
# ############################################################
#
# [Device] Utilisation de : cuda
#   GPU : NVIDIA GeForce RTX 3050 6GB Laptop GPU
#   VRAM disponible : 6.4 GB
#
# [Data] Chargement depuis ./dataset/multiclass
# [Multiclass] Classes : ['mure_malade', 'mure_saint', 'tropmure_malade', 'tropmure_saint', 'vert_malade', 'vert_sain']
# [Multiclass] Train: 5108, Val: 661, Test: 505
#
# [Model] Chargement efficientnet_b0 pré-entraîné (ImageNet)
# [EfficientNet-B0] Params total: 4,337,026 | Entraînables: 329,478 (7.6%)
#
# [Training] Démarrage de l'entraînement en 2 phases
# [Criterion] CrossEntropyLoss
#
# ==================================================
# PHASE 1 : Feature Extraction — 10 epochs
# ==================================================
# Epoch 01/10 | Train Loss: 0.3705 Acc: 0.889 | Val Loss: 0.1265 Acc: 0.962
# Epoch 02/10 | Train Loss: 0.1677 Acc: 0.946 | Val Loss: 0.0943 Acc: 0.979
# Epoch 03/10 | Train Loss: 0.1313 Acc: 0.955 | Val Loss: 0.0794 Acc: 0.977
# Epoch 04/10 | Train Loss: 0.1210 Acc: 0.961 | Val Loss: 0.0740 Acc: 0.976
# Epoch 05/10 | Train Loss: 0.1206 Acc: 0.959 | Val Loss: 0.0705 Acc: 0.983
# Epoch 06/10 | Train Loss: 0.1095 Acc: 0.963 | Val Loss: 0.0693 Acc: 0.979
# Epoch 07/10 | Train Loss: 0.1108 Acc: 0.964 | Val Loss: 0.0719 Acc: 0.977
# Epoch 08/10 | Train Loss: 0.0888 Acc: 0.971 | Val Loss: 0.0780 Acc: 0.977
# Epoch 09/10 | Train Loss: 0.0965 Acc: 0.970 | Val Loss: 0.0720 Acc: 0.982
# Epoch 10/10 | Train Loss: 0.0896 Acc: 0.971 | Val Loss: 0.0523 Acc: 0.985
#
# ==================================================
# PHASE 2 : Fine-tuning — 10 epochs
# ==================================================
# Epoch FT 01/10 | Train Loss: 0.0723 Acc: 0.976 | Val Loss: 0.0515 Acc: 0.982
# Epoch FT 02/10 | Train Loss: 0.0605 Acc: 0.978 | Val Loss: 0.0553 Acc: 0.986
# Epoch FT 03/10 | Train Loss: 0.0526 Acc: 0.983 | Val Loss: 0.0474 Acc: 0.988
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 15
#      11     sys.argv = ['run_module_a.py', '--task', 'multiclass', '--data_dir', './dataset/multiclass', '--arch', 'efficientnet_b0']
#      12     args = parse_args()
#      13     run_single_experiment(args, args.arch)
#      14 finally:
# ---> 15     sys.argv = original_argv
#
# Cell In[52], line 400, in run_single_experiment(args, architecture)
#     396     num_classes = 1 if args.task == "binary" else len(class_names)
#     397     print(f"\n[Model] Chargement {architecture} pré-entraîné (ImageNet)")
#     398     model = build_model(architecture=architecture, num_classes=num_classes, task=args.task, freeze_backbone=True).to(device)
#     399     print(f"\n[Training] Démarrage de l'entraînement en 2 phases")
# --> 400     result = train_full(model, train_loader, val_loader, device, args.task, args.epochs_phase1, args.epochs_phase2, args.output_dir, architecture)
#     401     model = result["model"]
#     402     print(f"\n[Evaluation] Test set — données jamais vues pendant l'entraînement")
#     403     if args.task == "binary":
#
# Cell In[52], line 267, in train_full(model, train_loader, val_loader, device, task, epochs_phase1, epochs_phase2, output_dir, architecture)
#     263     scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)
#     264     patience_counter = 0
#     265
#     266     for epoch in range(1, epochs_phase2 + 1):
# --> 267         train_metrics = train_one_epoch(model, train_loader, optimizer, criterion, device, task)
#     268         val_metrics = evaluate(model, val_loader, criterion, device, task)
#     269         scheduler.step(val_metrics["loss"])
#     270         history["train_loss"].append(train_metrics["loss"])
#
# Cell In[52], line 166, in train_one_epoch(model, loader, optimizer, criterion, device, task)
#     162             loss = criterion(outputs, labels)
#     163             preds = outputs.argmax(dim=1)
#     164         loss.backward()
#     165         optimizer.step()
# --> 166         total_loss += loss.item() * images.size(0)
#     167         correct += (preds == labels).sum().item()
#     168         total += images.size(0)
#     169     return {"loss": total_loss / total, "accuracy": correct / total}
#
# KeyboardInterrupt:

# %%
import os
from pathlib import Path
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# =====================================================================
# 1. CONFIGURATION
# =====================================================================
model_weights_path = "./outputs/module_a/best_efficientnet_b0_binary.pth"  # chemin vers le fichier .pth du modèle entraîné 
test_dir = Path("./dossier_test_bananes")   # DOIT contenir deux sous-dossiers : bananes_export/ et bananes_rejetees/
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
class_names = ["bananes_export", "bananes_rejetees"]   # exactement les noms des sous-dossiers

# =====================================================================
# 2. TRANSFORMATIONS (identiques à l'entraînement)
# =====================================================================
transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# =====================================================================
# 3. CHARGEMENT DU DATASET TEST (avec sous-dossiers par classe)
# =====================================================================
if not test_dir.exists():
    raise FileNotFoundError(f"Dossier {test_dir} introuvable. Crée les sous-dossiers 'bananes_export' et 'bananes_rejetees'.")

test_dataset = datasets.ImageFolder(root=test_dir, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f"Classes trouvées : {test_dataset.classes}")
print(f"Nombre d'images test : {len(test_dataset)}")

# =====================================================================
# 4. CHARGEMENT DU MODÈLE
# =====================================================================
from torchvision.models import efficientnet_b0

model = efficientnet_b0(weights=None)
num_ftrs = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.2),
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Dropout(p=0.2),
    nn.Linear(256, 1)
)
model.load_state_dict(torch.load(model_weights_path, map_location=device))
model.to(device)
model.eval()

# =====================================================================
# 5. INFÉRENCE ET CALCUL DES MÉTRIQUES
# =====================================================================
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        probs = torch.sigmoid(outputs.squeeze())
        preds = (probs > 0.5).long()
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

# =====================================================================
# 6. AFFICHAGE DES RÉSULTATS
# =====================================================================
print("\n" + "="*60)
print("RAPPORT DE CLASSIFICATION SUR LE DOSSIER TEST")
print("="*60)
print(classification_report(all_labels, all_preds, target_names=class_names))

cm = confusion_matrix(all_labels, all_preds)
tn, fp, fn, tp = cm.ravel()
print("\n" + "-"*60)
print("ANALYSE DÉTAILLÉE (pour le rapport PHP)")
print("-"*60)
print(f"✅ Bananes Export bien classées (Vrais Négatifs)      : {tn}")
print(f"❌ Bananes Rejetées classées Export par erreur (FN)   : {fn}  ← RISQUE CLIENT")
print(f"⚠️  Bananes Export classées Rejetées par erreur (FP)  : {fp}  ← PERTE REVENU")
print(f"✅ Bananes Rejetées bien classées (Vrais Positifs)    : {tp}")
print(f"→ Précision globale : {(tp+tn)/(tp+tn+fp+fn)*100:.2f}%")
print("="*60)

# Optionnel : afficher les images mal classées
misclassified = []
for idx, (true, pred) in enumerate(zip(all_labels, all_preds)):
    if true != pred:
        img_path = Path(test_dataset.samples[idx][0])   # ← conversion ici
        misclassified.append((img_path, true, pred))

if misclassified:
    print("\n🔄 Images mal classées :")
    for path, true, pred in misclassified:
        print(f"   {path.name} : vrai={class_names[true]} | prédit={class_names[pred]}")
else:
    print("\n✅ Aucune erreur ! Parfait sur ce test.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 36
#      32 # =====================================================================
#      33 if not test_dir.exists():
#      34     raise FileNotFoundError(f"Dossier {test_dir} introuvable. Crée les sous-dossiers 'bananes_export' et 'bananes_rejetees'.")
#      35
# ---> 36 test_dataset = datasets.ImageFolder(root=test_dir, transform=transform_test)
#      37 test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
#      38
#      39 print(f"Classes trouvées : {test_dataset.classes}")
#
# File c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
#     333         target_transform=target_transform,
#     334         is_valid_file=is_valid_file,
#     335         allow_empty=allow_empty,
#     336     )
#     337     self.imgs = self.samples
#
# File c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\folder.py:150, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     148 super().__init__(root, transform=transform, target_transform=target_transform)
#     149 classes, class_to_idx = self.find_classes(self.root)
# --> 150 samples = self.make_dataset(
#     151     self.root,
#     152     class_to_idx=class_to_idx,
#     153     extensions=extensions,
#     154     is_valid_file=is_valid_file,
#     155     allow_empty=allow_empty,
#     156 )
#     158 self.loader = loader
#     159 self.extensions = extensions
#
# File c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\folder.py:203, in DatasetFolder.make_dataset(directory, class_to_idx, extensions, is_valid_file, allow_empty)
#     198 if class_to_idx is None:
#     199     # prevent potential bug since make_dataset() would use the class_to_idx logic of the
#     200     # find_classes() function, instead of using that of the find_classes() method, which
#     201     # is potentially overridden and thus could have a different logic.
#     202     raise ValueError("The class_to_idx parameter cannot be None.")
# --> 203 return make_dataset(
#     204     directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file, allow_empty=allow_empty
#     205 )
#
# File c:\Users\naren\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\datasets\folder.py:104, in make_dataset(directory, class_to_idx, extensions, is_valid_file, allow_empty)
#     102     if extensions is not None:
#     103         msg += f"Supported extensions are: {extensions if isinstance(extensions, str) else ', '.join(extensions)}"
# --> 104     raise FileNotFoundError(msg)
#     106 return instances
#
# FileNotFoundError: Found no valid file for the classes bananes_export, bananes_rejetees. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
# ============================================================================
# ÉVALUATION DU MODÈLE MULTI-CLASSES SUR UN DOSSIER TEST DÉDIÉ
# ============================================================================
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import datasets, models
from torch.utils.data import DataLoader
from pathlib import Path
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# 1. Configuration
multiclass_weights = "./outputs/module_a/best_efficientnet_b0_multiclass.pth"
test_dir = Path("./dossier_test_multiclass")   # à créer avec 3 sous-dossiers
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 2. Transformations (identiques à l'entraînement)
transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 3. Chargement du dataset test (vérifier que les sous-dossiers existent)
if not test_dir.exists():
    raise FileNotFoundError(f"Dossier {test_dir} introuvable. Crée les sous-dossiers : "
                            f"defaut_mecanique, maladie_fongique, mure.")
test_dataset = datasets.ImageFolder(root=test_dir, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

class_names = test_dataset.classes
print(f"Classes trouvées : {class_names}")
print(f"Nombre d'images test : {len(test_dataset)}")

# 4. Chargement du modèle multi‑classes
model = models.efficientnet_b0(weights=None)
num_ftrs = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Dropout(p=0.2),
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Dropout(p=0.2),
    nn.Linear(256, len(class_names))   # 3 classes
)
model.load_state_dict(torch.load(multiclass_weights, map_location=device))
model.to(device)
model.eval()

# 5. Inférence
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        preds = outputs.argmax(dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

# 6. Métriques
print("\n" + "="*60)
print("RAPPORT DE CLASSIFICATION – MODÈLE MULTI-CLASSES")
print("="*60)
print(classification_report(all_labels, all_preds, target_names=class_names))

cm = confusion_matrix(all_labels, all_preds)
print("\nMatrice de confusion (valeurs absolues) :")
print(cm)
# Normalisation par ligne (vrais états)
cm_norm = cm.astype('float') / cm.sum(axis=1, keepdims=True)
print("\nMatrice de confusion normalisée (probabilités) :")
print(np.round(cm_norm, 2))

# Optionnel : afficher les images mal classées
misclassified = []
for idx, (true, pred) in enumerate(zip(all_labels, all_preds)):
    if true != pred:
        img_path = test_dataset.samples[idx][0]
        misclassified.append((Path(img_path).name, class_names[true], class_names[pred]))
if misclassified:
    print("\n🔄 Images mal classées :")
    for name, true_cls, pred_cls in misclassified:
        print(f"   {name} : vrai={true_cls} | prédit={pred_cls}")
else:
    print("\n✅ Aucune erreur !")
